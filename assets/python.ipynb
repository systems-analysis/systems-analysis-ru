# %%
genome = 'ATGGFI'

# %%
genome[0]

# %%
genome[5]

# %%
genome[-1]

# %%
for i in range(4):
    print(genome[i])

# %%
for i in range(len(genome)):
    print(genome[i])

# %%
for c in genome:
    print(c)

# %%
genome = input()
cnt = 0
for nucl in genome:
    if nucl == 'C':
        cnt +=1
print(cnt)

# %%
genome = input()
print(genome.count('C'))

# %%
s = input('Enter string:  ')
t = input('Enter element: ')
z = input('Enter element replase:  ')
print(s.upper())
print(s.lower())
print(t, '=', s.count(t))
print(s.find(t))
print(s.replace(t, z))
# Out:
# Enter string:  Hello, world
# Enter element: l
# Enter element replase:  x
# HELLO, WORLD
# hello, world
# l = 3
# 2
# Hexxo, worxd

# %%
s = input()
s.upper().count('gt'.upper())
# Out:
# JHLkhjkh
# 0

# %%
s = input()
print()
print('s[1] = ', s[1])
print('s[2:5] = ', s[2:5])
print('s[:4] = ', s[:4])
print('s[-2] = ', s[-2])
print("s[2:-2] =", s[2:-2])
print("s[::-1] = ", s[::-1])
# Out:
# Hello world
#
# s[1] =  e
# s[2:5] =  llo
# s[:4] =  Hell
# s[-2] =  l
# s[2:-2] = llo wor
# s[::-1] =  dlrow olleH

# %%
s = input()
r = s[::-1]
if s == r:
    print('Yes')
else:
    print('No')
# Out:
# jjjjj
# Yes
